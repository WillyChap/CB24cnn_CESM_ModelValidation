# %%
import wk_spectra.wk_analysis as wka

# %%
Bebop = wka.wk_analysis()
filenn = '/glade/scratch/wchapman/ADF/f.e21.DAcompset.f09_d025_Seasonal_stochai_UV_05_1982_MJO_v3/ts/f.e21.DAcompset.f09_d025_Seasonal_stochai_UV_05_1982_MJO_v3.h1.PRECT.1982010100000-2010123000000.nc'
Bebop.import_netcdf(file=filenn,varname='PRECT',latname='lat',latBound=15)
Bebop.wheeler_kiladis_spectra(spd=1,nDayWin=96,nDaySkip=30,max_freq=0.5,max_wn=20)
Bebop.print_status()
# Out:
# wk_analysis object initiated and ready to receive data.
# The file /glade/scratch/wchapman/ADF/f.e21.DAcompset.f09_d025_Seasonal_stochai_UV_05_1982_MJO_v3/ts/f.e21.DAcompset.f09_d025_Seasonal_stochai_UV_05_1982_MJO_v3.h1.PRECT.1982010100000-2010123000000.nc has been imported
# The Wheeler-Kiladis Analysis is complete.
# data_status = NetCDF File
# analysis_status = Complete
# plots_available = No
# file = /glade/scratch/wchapman/ADF/f.e21.DAcompset.f09_d025_Seasonal_stochai_UV_05_1982_MJO_v3/ts/f.e21.DAcompset.f09_d025_Seasonal_stochai_UV_05_1982_MJO_v3.h1.PRECT.1982010100000-2010123000000.nc
# varname = PRECT
# latname = lat
# latBound = 15
# spd = 1
# nDayWin = 96
# nDaySkip = 30
# max_freq = 0.5
# max_wn = 20

# %%
clevels = [0.5,0.6,.7,.8,.9,1,1.1,1.15,1.2,1.25,1.3,1.35,1.4,1.45,1.5,1.6]
Bebop.plot_background_removed(labels=True,figsize=[15,10],contour_range=(0.5,2,0.1),text_size=18,clevels=clevels)
