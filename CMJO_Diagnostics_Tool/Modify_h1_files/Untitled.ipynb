# %%
import xarray as xr
import numpy as np
import pandas as pd

# %%
dir_in = '/glade/derecho/scratch/wchapman/ADF/f.e.FTORCHmjo_CNNmjo/ts/'
fin = 'f.e.FTORCHmjo_CNNmjo.cam.h1.FLUT.1979010100000-2010122200000.nc'

# %%
DS = xr.open_dataset(dir_in+fin)

# %%
DS.to_netcdf(dir_in+'/save_test.nc')

# %%
DS['FLUT'].sel(lat=20,lon=20,method='nearest').isel(time=slice(1,2000)).plot()

# %%
DS3=xr.open_dataset('/glade/derecho/scratch/wchapman/ADF/f.e.FTORCHmjo_meanGPU_exp001/ts/f.e.FTORCHmjo_meanGPU_exp001.cam.h1.FLUT.1979010100000-2010123100000.nc')

# %%
DS3['FLUT'].sel(lat=20,lon=20,method='nearest').isel(time=slice(1,2000)).plot()
