# %%
import xarray as xr

# %%
MEAN DTCOND,U,V,T,Q

# %%
dir = '/glade/derecho/scratch/wchapman/ADF/f.e.FTORCHmjo_CNTRLmjo_DT//ts/climo/'
filly = 'f.e.FTORCHmjo_CNTRLmjo_DT.cam.h1.V.anomalies.1979010100000-1990122200000.nc'
DS = xr.open_dataset(dir+filly)
DS['V'].isel(time=200).sel(lev=200,method='nearest').plot()
